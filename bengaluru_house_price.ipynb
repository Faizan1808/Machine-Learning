# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read dataset
df = pd.read_csv('Bengaluru_House_Data.csv')
df.tail()
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %%
# shape of dataset
df.shape
# Out:
# (13320, 9)

# %%
#check the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
#check null values
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
#check the percentage of missing values
(df.isnull().sum()/len(df))*100
# Out:
# area_type        0.000000
# availability     0.000000
# location         0.007508
# size             0.120120
# society         41.306306
# total_sqft       0.000000
# bath             0.548048
# balcony          4.572072
# price            0.000000
# dtype: float64

# %%
#drop the society 
df.drop(['society'], axis=1,inplace=True)

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#   total_sqft  bath  balcony   price
# 0       1056   2.0      1.0   39.07
# 1       2600   5.0      3.0  120.00
# 2       1440   2.0      3.0   62.00
# 3       1521   3.0      1.0   95.00
# 4       1200   2.0      1.0   51.00

# %%
# check the missing
df.loc[df['size'].isnull()]
# Out:
#         area_type          availability        location size  society  \
# 579    Plot  Area  Immediate Possession  Sarjapur  Road  NaN  Asiss B
# 1775   Plot  Area  Immediate Possession        IVC Road  NaN  Orana N
# 2264   Plot  Area  Immediate Possession    Banashankari  NaN      NaN
# 2809   Plot  Area  Immediate Possession  Sarjapur  Road  NaN  AsdiaAr
# 2862   Plot  Area  Immediate Possession     Devanahalli  NaN  Ajleyor
# 5333   Plot  Area  Immediate Possession     Devanahalli  NaN  Emngs S
# 6423   Plot  Area  Immediate Possession      Whitefield  NaN  SRniaGa
# 6636   Plot  Area  Immediate Possession          Jigani  NaN  S2enste
# 6719   Plot  Area  Immediate Possession         Hoskote  NaN  SJowsn
# 7680   Plot  Area  Immediate Possession    Kasavanhalli  NaN      NaN
# 8306   Plot  Area  Immediate Possession          Anekal  NaN  Vaensnd
# 8565   Plot  Area  Immediate Possession      Carmelaram  NaN  Ocezes
# 8703   Plot  Area  Immediate Possession     Mysore Road  NaN  Naoden
# 10634  Plot  Area  Immediate Possession      Rajankunte  NaN      NaN
# 11019  Plot  Area  Immediate Possession       Yelahanka  NaN  Saaveha
# 11569  Plot  Area  Immediate Possession      Hosur Road  NaN  AVeldun
#
#         total_sqft  bath  balcony    price
# 579    1200 - 2400   NaN      NaN   34.185
# 1775   2000 - 5634   NaN      NaN  124.000
# 2264          2400   NaN      NaN  460.000
# 2809   1200 - 2400   NaN      NaN   28.785
# 2862   1500 - 2400   NaN      NaN   46.800
# 5333   2100 - 5405   NaN      NaN  177.115
# 6423          2324   NaN      NaN   26.730
# 6636          1500   NaN      NaN   25.490
# 6719    800 - 2660   NaN      NaN   28.545
# 7680          5000   NaN      NaN  400.000
# 8306          1453   NaN      NaN   16.500
# 8565          2000   NaN      NaN  120.000
# 8703   1200 - 2400   NaN      NaN   42.300
# 10634         1575   NaN      NaN   31.110
# 11019  1200 - 1800   NaN      NaN   12.750
# 11569         1350   NaN      NaN    8.440

# %%
df['size'].fillna(0, inplace=True)

# %%
df['bhk'] = df['size'].apply(lambda x : int(str(x).split(' ')[0]))

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#   total_sqft  bath  balcony   price  bhk
# 0       1056   2.0      1.0   39.07    2
# 1       2600   5.0      3.0  120.00    4
# 2       1440   2.0      3.0   62.00    3
# 3       1521   3.0      1.0   95.00    3
# 4       1200   2.0      1.0   51.00    2

# %%
df.drop(['size'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          1
# total_sqft        0
# bath             73
# balcony         609
# price             0
# bhk               0
# dtype: int64

# %%
df.loc[df['bath'].isnull()]
# Out:
#                   area_type          availability        location  \
# 56           Built-up  Area                20-Feb     Devanahalli
# 81           Built-up  Area                18-Oct     Hennur Road
# 224    Super built-up  Area                19-Dec     Devanahalli
# 344    Super built-up  Area                21-Dec  Kanakpura Road
# 579              Plot  Area  Immediate Possession  Sarjapur  Road
# ...                     ...                   ...             ...
# 11496  Super built-up  Area                21-Dec  Kanakpura Road
# 11569            Plot  Area  Immediate Possession      Hosur Road
# 12768        Built-up  Area                18-Mar    Bettahalsoor
# 12861  Super built-up  Area                21-Dec        KR Puram
# 13240  Super built-up  Area         Ready To Move     Devanahalli
#
#         total_sqft  bath  balcony    price  bhk
# 56     3010 - 3410   NaN      NaN  192.000    4
# 81     2957 - 3450   NaN      NaN  224.500    4
# 224    1520 - 1740   NaN      NaN   74.820    3
# 344            525   NaN      NaN   21.530    1
# 579    1200 - 2400   NaN      NaN   34.185    0
# ...            ...   ...      ...      ...  ...
# 11496          525   NaN      NaN   27.000    1
# 11569         1350   NaN      NaN    8.440    0
# 12768         3210   NaN      NaN  353.000    5
# 12861  2204 - 2362   NaN      NaN  121.000    4
# 13240  1020 - 1130   NaN      NaN   52.570    1
#
# [73 rows x 8 columns]

# %%
df.head(20)
# Out:
#                area_type   availability                  location total_sqft  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II       1056
# 1             Plot  Area  Ready To Move          Chikka Tirupathi       2600
# 2         Built-up  Area  Ready To Move               Uttarahalli       1440
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli       1521
# 4   Super built-up  Area  Ready To Move                  Kothanur       1200
# 5   Super built-up  Area  Ready To Move                Whitefield       1170
# 6   Super built-up  Area         18-May          Old Airport Road       2732
# 7   Super built-up  Area  Ready To Move              Rajaji Nagar       3300
# 8   Super built-up  Area  Ready To Move              Marathahalli       1310
# 9             Plot  Area  Ready To Move              Gandhi Bazar       1020
# 10  Super built-up  Area         18-Feb                Whitefield       1800
# 11            Plot  Area  Ready To Move                Whitefield       2785
# 12  Super built-up  Area  Ready To Move        7th Phase JP Nagar       1000
# 13        Built-up  Area  Ready To Move                 Gottigere       1100
# 14            Plot  Area  Ready To Move                  Sarjapur       2250
# 15  Super built-up  Area  Ready To Move               Mysore Road       1175
# 16  Super built-up  Area  Ready To Move             Bisuvanahalli       1180
# 17  Super built-up  Area  Ready To Move     Raja Rajeshwari Nagar       1540
# 18  Super built-up  Area  Ready To Move     Ramakrishnappa Layout       2770
# 19  Super built-up  Area  Ready To Move        Manayata Tech Park       1100
#
#     bath  balcony   price  bhk
# 0    2.0      1.0   39.07    2
# 1    5.0      3.0  120.00    4
# 2    2.0      3.0   62.00    3
# 3    3.0      1.0   95.00    3
# 4    2.0      1.0   51.00    2
# 5    2.0      1.0   38.00    2
# 6    4.0      NaN  204.00    4
# 7    4.0      NaN  600.00    4
# 8    3.0      1.0   63.25    3
# 9    6.0      NaN  370.00    6
# 10   2.0      2.0   70.00    3
# 11   5.0      3.0  295.00    4
# 12   2.0      1.0   38.00    2
# 13   2.0      2.0   40.00    2
# 14   3.0      2.0  148.00    3
# 15   2.0      2.0   73.50    2
# 16   3.0      2.0   48.00    3
# 17   3.0      3.0   60.00    3
# 18   4.0      2.0  290.00    3
# 19   2.0      2.0   48.00    2

# %%
df.loc[df['bhk'] == df['bath']]
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# 5      Super built-up  Area  Ready To Move                Whitefield
# 6      Super built-up  Area         18-May          Old Airport Road
# ...                     ...            ...                       ...
# 13312  Super built-up  Area  Ready To Move                 Bellandur
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#       total_sqft  bath  balcony   price  bhk
# 0           1056   2.0      1.0   39.07    2
# 3           1521   3.0      1.0   95.00    3
# 4           1200   2.0      1.0   51.00    2
# 5           1170   2.0      1.0   38.00    2
# 6           2732   4.0      NaN  204.00    4
# ...          ...   ...      ...     ...  ...
# 13312       1262   2.0      2.0   47.00    2
# 13314       1715   3.0      3.0  112.00    3
# 13317       1141   2.0      1.0   60.00    2
# 13318       4689   4.0      1.0  488.00    4
# 13319        550   1.0      1.0   17.00    1
#
# [10069 rows x 8 columns]

# %%
df.drop(['bath'],axis=1,inplace=True)

# %%
df.loc[df['balcony'].isnull()]
# Out:
#                   area_type   availability                 location  \
# 6      Super built-up  Area         18-May         Old Airport Road
# 7      Super built-up  Area  Ready To Move             Rajaji Nagar
# 9                Plot  Area  Ready To Move             Gandhi Bazar
# 34           Built-up  Area  Ready To Move            Kasturi Nagar
# 40           Built-up  Area  Ready To Move            Murugeshpalya
# ...                     ...            ...                      ...
# 13277            Plot  Area  Ready To Move      Kundalahalli Colony
# 13279            Plot  Area  Ready To Move  Vishwanatha Nagenahalli
# 13306            Plot  Area  Ready To Move    Rajarajeshwari Nagara
# 13309  Super built-up  Area  Ready To Move             Yeshwanthpur
# 13316  Super built-up  Area  Ready To Move            Richards Town
#
#       total_sqft  balcony   price  bhk
# 6           2732      NaN  204.00    4
# 7           3300      NaN  600.00    4
# 9           1020      NaN  370.00    6
# 34          1925      NaN  125.00    3
# 40          1296      NaN   81.00    2
# ...          ...      ...     ...  ...
# 13277       1400      NaN  218.00    7
# 13279       1200      NaN  130.00    6
# 13306       1200      NaN  325.00    4
# 13309       1675      NaN   92.13    3
# 13316       3600      NaN  400.00    4
#
# [609 rows x 7 columns]

# %%
df.loc[df['balcony'].isnull()]['availability'].value_counts()
# Out:
# Ready To Move           503
# Immediate Possession     16
# 18-Dec                   16
# 18-May                   13
# 18-Mar                   13
# 18-Apr                   10
# 21-Dec                    5
# 18-Feb                    5
# 18-Jul                    3
# 19-Dec                    3
# 18-Jun                    3
# 15-Oct                    2
# 19-Mar                    2
# 15-Nov                    2
# 19-Jul                    2
# 22-May                    2
# 19-May                    1
# 19-Jun                    1
# 18-Oct                    1
# 17-Feb                    1
# 18-Sep                    1
# 20-Feb                    1
# 17-Aug                    1
# 17-Sep                    1
# 19-Oct                    1
# Name: availability, dtype: int64

# %%
df.loc[df['availability'] == 'Ready To Move']
# Out:
#                   area_type   availability               location total_sqft  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi       2600
# 2            Built-up  Area  Ready To Move            Uttarahalli       1440
# 3      Super built-up  Area  Ready To Move     Lingadheeranahalli       1521
# 4      Super built-up  Area  Ready To Move               Kothanur       1200
# 5      Super built-up  Area  Ready To Move             Whitefield       1170
# ...                     ...            ...                    ...        ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout       1715
# 13315        Built-up  Area  Ready To Move             Whitefield       3453
# 13316  Super built-up  Area  Ready To Move          Richards Town       3600
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar       1141
# 13319  Super built-up  Area  Ready To Move           Doddathoguru        550
#
#        balcony  price  bhk
# 1          3.0  120.0    4
# 2          3.0   62.0    3
# 3          1.0   95.0    3
# 4          1.0   51.0    2
# 5          1.0   38.0    2
# ...        ...    ...  ...
# 13314      3.0  112.0    3
# 13315      0.0  231.0    5
# 13316      NaN  400.0    4
# 13317      1.0   60.0    2
# 13319      1.0   17.0    1
#
# [10581 rows x 7 columns]

# %%
df['balcony'].fillna(0, inplace=True)

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# total_sqft      0
# balcony         0
# price           0
# bhk             0
# dtype: int64

# %%
df.head()
# Out:
#               area_type   availability                  location total_sqft  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II       1056
# 1            Plot  Area  Ready To Move          Chikka Tirupathi       2600
# 2        Built-up  Area  Ready To Move               Uttarahalli       1440
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli       1521
# 4  Super built-up  Area  Ready To Move                  Kothanur       1200
#
#    balcony   price  bhk
# 0      1.0   39.07    2
# 1      3.0  120.00    4
# 2      3.0   62.00    3
# 3      1.0   95.00    3
# 4      1.0   51.00    2

# %%
# Example
# use of isinstance
#x = 2
#isinstance('2',int)

# %%
help(isinstance)
# Out:
# Help on built-in function isinstance in module builtins:
#
# isinstance(obj, class_or_tuple, /)
#     Return whether an object is an instance of a class or of a subclass thereof.
#
#     A tuple, as in ``isinstance(x, (A, B, ...))``, may be given as the target to
#     check against. This is equivalent to ``isinstance(x, A) or isinstance(x, B)
#     or ...`` etc.

# %%
#df['total_sqft'] = df['total_sqft'].str.split()

# %%
#def cleansqft(x):
    #if isinstance(x,int):
     #   return x
    #elif len(x.split('-')) == 2:
    #    a,b = x.split('-')
   #     s = (float(a) + float(b))/2
  #      return s
 #   else:
#        return none

# %%
#cleansqft('1000-1100')

# %%
#cleansqft(1200)

# %%
#df[['total_sqft']].applymap(cleansqft)

# %%
df['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
df['area_type'].head(5)
# Out:
# 0    Super built-up  Area
# 1              Plot  Area
# 2          Built-up  Area
# 3    Super built-up  Area
# 4    Super built-up  Area
# Name: area_type, dtype: object

# %%
pd.get_dummies(df['area_type'])
# Out:
#        Built-up  Area  Carpet  Area  Plot  Area  Super built-up  Area
# 0                   0             0           0                     1
# 1                   0             0           1                     0
# 2                   1             0           0                     0
# 3                   0             0           0                     1
# 4                   0             0           0                     1
# ...               ...           ...         ...                   ...
# 13315               1             0           0                     0
# 13316               0             0           0                     1
# 13317               1             0           0                     0
# 13318               0             0           0                     1
# 13319               0             0           0                     1
#
# [13319 rows x 4 columns]

# %%
df['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '20-Feb',
#        '18-Apr', '20-Aug', '18-Oct', '19-Mar', '17-Sep', '18-Dec',
#        '17-Aug', '19-Apr', '18-Jun', '22-Dec', '22-Jan', '18-Aug',
#        '19-Jan', '17-Jul', '18-Jul', '21-Jun', '20-May', '19-Aug',
#        '18-Sep', '17-May', '17-Jun', '21-May', '18-Jan', '20-Mar',
#        '17-Dec', '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb',
#        'Immediate Possession', '19-May', '17-Nov', '20-Oct', '20-Jun',
#        '19-Feb', '21-Oct', '21-Jan', '17-Mar', '17-Apr', '22-May',
#        '19-Oct', '21-Jul', '21-Nov', '21-Mar', '16-Dec', '22-Mar',
#        '20-Jan', '21-Sep', '21-Aug', '14-Nov', '19-Nov', '15-Nov',
#        '16-Jul', '15-Jun', '17-Feb', '20-Nov', '20-Jul', '16-Sep',
#        '15-Oct', '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan',
#        '16-Nov', '20-Apr', '16-Jan', '14-Jul'], dtype=object)

# %%
df['location'].nunique()
# Out:
# 1305

# %%
df['location'].value_counts()
# Out:
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'total_sqft', 'balcony',
#        'price', 'bhk'],
#       dtype='object')

# %%
df.drop(['availability', 'location', 'total_sqft'], axis=1,inplace=True)

# %%
df.head()
# Out:
#               area_type  balcony   price  bhk
# 0  Super built-up  Area      1.0   39.07    2
# 1            Plot  Area      3.0  120.00    4
# 2        Built-up  Area      3.0   62.00    3
# 3  Super built-up  Area      1.0   95.00    3
# 4  Super built-up  Area      1.0   51.00    2

# %%
new_df = pd.get_dummies(df)
new_df.head()
# Out:
#    balcony   price  bhk  area_type_Built-up  Area  area_type_Carpet  Area  \
# 0      1.0   39.07    2                         0                       0
# 1      3.0  120.00    4                         0                       0
# 2      3.0   62.00    3                         1                       0
# 3      1.0   95.00    3                         0                       0
# 4      1.0   51.00    2                         0                       0
#
#    area_type_Plot  Area  area_type_Super built-up  Area
# 0                     0                               1
# 1                     1                               0
# 2                     0                               0
# 3                     0                               1
# 4                     0                               1

# %%
# dependent & independent variable
x = new_df.drop(['price'],axis=1)
y = new_df['price']

# %%
x.head()
# Out:
#    balcony  bhk  area_type_Built-up  Area  area_type_Carpet  Area  \
# 0      1.0    2                         0                       0
# 1      3.0    4                         0                       0
# 2      3.0    3                         1                       0
# 3      1.0    3                         0                       0
# 4      1.0    2                         0                       0
#
#    area_type_Plot  Area  area_type_Super built-up  Area
# 0                     0                               1
# 1                     1                               0
# 2                     0                               0
# 3                     0                               1
# 4                     0                               1

# %%
y.head()
# Out:
# 0     39.07
# 1    120.00
# 2     62.00
# 3     95.00
# 4     51.00
# Name: price, dtype: float64

# %%
x.shape
# Out:
# (13319, 6)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,random_state=42)

# %%
x_train.shape,y_train.shape
# Out:
# ((9323, 6), (9323,))

# %%
x_test.shape,y_test.shape
# Out:
# ((3996, 6), (3996,))

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()
lr_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
tr_pred = lr_model.predict(x_train)
ts_pred = lr_model.predict(x_test)
print(tr_pred.shape)
print(ts_pred.shape)
# Out:
# (9323,)
# (3996,)

# %%
from sklearn.metrics import r2_score,mean_squared_error
print(f'traning mse - {mean_squared_error(y_train,tr_pred)}')
print(f'traning r2-score - {r2_score(y_train,tr_pred)}')

print(f'testing mse - {mean_squared_error(y_test,ts_pred)}')
print(f'testing r2-score - {r2_score(y_test,ts_pred)}')
# Out:
# traning mse - 19210.88379178513
# traning r2-score - 0.16775260785970803
# testing mse - 16341.222273768411
# testing r2-score - 0.1874785295451119
